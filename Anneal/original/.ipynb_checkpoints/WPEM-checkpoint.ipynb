# %% [markdown]
# # background intensity

# %%
import sys
import pandas as pd
Yourdir = '/Users/Jacob/Documents/WpenPattern'
sys.path.append(Yourdir)
import WpenPattern.BacDeduct as BacDeduct

# %%
TF = BacDeduct.TwiceFilter()
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
Var = TF.FFTandSGFilter(intensity_csv,lowAngleRange=32,poly_n=8,bac_split=12,bac_num=200 )
Var
# Out:
# 15.508867383109555

# %% [markdown]
# # WPEM fitting

# %%
if __name__ == "__main__":

    import WpenPattern.WPEMModel as WPEMModel

    # The wavelength is set according to the actual light source
    wavelength = [1.540593, 1.544414]
    
    # Enter the file name to read on the right side of the equal sign. 
    # Please remember to quote, string.
    
    # The file name of non-background data (2theta-intensity data)
    no_bac_intensity_file = "no_bac_intensity.csv" 
    # The file name of raw/original data (2theta-intensity data)
    original_file = "intensity.csv"  
    # The file name of background data (2theta-intensity data)
    bacground_file = "bac.csv"  


    # Input the initial lattice constants {a, b, c, α, β, γ}, whose values need to be assumed at initialization.
    
    Lattice_constants = [
                         [3.3065, 3.3065, 3.3065, 90.0, 90.0, 90.0,],
                        ]
  
    # Lattice_constants = [L_Cu,L_CuO,L_Cu2O]
    # Execute the model
    WPEMModel.Built().fit(
        wavelength, Var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
        subset_number=5,low_bound=30,up_bound=55,bta = 0.85, iter_max = 200, EXACT=True, 
        LogPrint = True, num = 5,asy_C = 0,cpu=6)
# Out:
# Started at Sat Apr 29 13:15:39 2023
# WPEM package : Whole Pattern fitting of powder X-ray diffraction by Expectation Maximum
# WPEM V2.0.0, March 2, 2022, MGI, SHU, Shanghai, CHINA.
# Reference paper : Doi
# ------------------------------------------------------------------
# Diffraction indexs have been obtained by WPEM
# The input crystal system is: Cubic The initial inputs : 3.3065 3.3065 3.3065 90.0 90.0 90.0
#  the largest measuring angle is : 45.00817 . Which is lower than the angle corresponding to max(H,K,L) which provided :  69.78786428459186
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 27
#      21 Lattice_constants = [
#      22                      [3.3065, 3.3065, 3.3065, 90.0, 90.0, 90.0,],
#      23                     ]
#      25 # Lattice_constants = [L_Cu,L_CuO,L_Cu2O]
#      26 # Execute the model
# ---> 27 WPEMModel.Built().fit(
#      28     wavelength, Var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file,
#      29     subset_number=5,low_bound=30,up_bound=55,bta = 0.85, iter_max = 200, EXACT=True,
#      30     LogPrint = True, num = 5,asy_C = 0,cpu=6)
#
# File /Users/Jacob/Documents/WpenPattern/WpenPattern/WPEMModel.py:106, in Built.fit(self, wavelength, Var, Lattice_constants, no_bac_intensity_file, original_file, bacground_file, two_theta_range, structure_factor, LogPrint, bta, bta_threshold, limit, iter_limit, w_limit, iter_max, lock_num, asy_C, s_angle, subset_number, low_bound, up_bound, MODEL, Macromolecule, cpu, num, EXACT, Cu_tao, Ave_Waves)
#     103 # whether or not print out the update log
#     104 if  LogPrint == True:
#     105     # Determine the latent parameters
# --> 106     Rp, Rwp, i_ter, flag = Inst_WPEM.cal_output_result()
#     107 elif  LogPrint == False:
#     108     Rp, Rwp, i_ter, flag = Inst_WPEM.cal_output_result_reduce()
#
# File /Users/Jacob/Documents/WpenPattern/WpenPattern/WPEMProcess.py:1295, in WPEM.cal_output_result(self)
#    1290 inten -= min_i
#    1292 area = self.theta_intensity_area(theta_data, inten)
#    1294 w_list, p1_list, p2_list, i_ter, flag, \
# -> 1295 ini_CL, mui_abc_set, i_out, bac_up, Rp, Rwp, Rsquare,crystal_sys_set = self.up_parameter(
#    1296                                            hkl_data,theta_data, inten, area, min_i, i_obser, bac,lmd)
#    1298 i_calc = i_out + min_i
#    1300 i_w_cal = []
#
# File /Users/Jacob/Documents/WpenPattern/WpenPattern/WPEMProcess.py:703, in WPEM.up_parameter(self, hkl_data, two_theta, intensity, area, min_i, i_obser, bac, lmd)
#     700 if np.array(ini_p).max() >= self.two_theta.max():
#     701     print(' the largest measuring angle is :', self.two_theta.max(),
#     702           '. Which is lower than the angle corresponding to max(H,K,L) which provided : ',np.array(ini_p).max())
# --> 703     raise NameError('NOTE! H K L values error')
#     705 n_k = len(ini_p)
#     708 if len(self.wavelength) == 1:
#
# NameError: NOTE! H K L values error
